# %%
import numpy as np
import tensorflow as tf
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Concatenate
from sklearn.preprocessing import StandardScaler, OneHotEncoder
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score,confusion_matrix,f1_score, roc_curve, auc,roc_auc_score
from ..Include.MLSMOTE import get_tail_label,get_index,get_minority_instace,MLSMOTE
from scipy.stats import yeojohnson

# %% [markdown]
# 找出适合OneHotEncoder的数据
#
# https://zhuanlan.zhihu.com/p/686452650

# %%
# 加载数据
x_train = np.load('../Training data/X_train.npy')  # 特征 (1000, 111)
y_train = np.load('../Training data/y_train.npy')  # 目标 (1000, 11)
x_test=np.load("../Testing data/X_test.npy")


x_train = pd.DataFrame(x_train).rename(columns={i: f"x_{i}" for i in range(111)})
y_train = pd.DataFrame(y_train).rename(columns={i: f"y_{i}" for i in range(11)})
x_test = pd.DataFrame(x_test).rename(columns={i: f"x_{i}" for i in range(111)})

#中位数填补
for column in x_train.columns:
    x_train.fillna({column: x_train[column].median()}, inplace=True)
    x_test.fillna({column: x_test[column].median()}, inplace=True)


# 找出非零值少于1%的列
threshold = 0.02  # 或者任何认为合适的值
cols_to_drop = [col for col in x_train.columns if (x_train[col] != 0).mean() < threshold]
# cols_to_drop += ["x_8",  "x_26", "x_29", "x_30", "x_32", "x_39", "x_50", "x_53", "x_54", "x_64", "x_68", "x_71", "x_93", "x_102"] #补充的一些特殊列
# 删除这些列
x_train.drop(columns=cols_to_drop, inplace=True)
x_test.drop(columns=cols_to_drop, inplace=True)
# Yeo-Johnson 变换
x_train = x_train.apply(lambda x: yeojohnson(x)[0])
x_test = x_test.apply(lambda x: yeojohnson(x)[0])



# 分别分离出适合scaler 和 one hot encode的features
dispersed = []; continues = []; ignored = []
for col in list(x_train.columns):
    col, len(x_train[col].value_counts())
    if 10 > len(x_train[col].value_counts()) > 2:
        dispersed.append(col)
    elif len(x_train[col].value_counts()) >= 10:
        continues.append(col)
    else: ignored.append(col)

# 特征缩放
scaler = StandardScaler()
x_train_continues = pd.DataFrame(scaler.fit_transform(x_train[continues]), columns=continues)
x_test_continues = pd.DataFrame(scaler.fit_transform(x_test[continues]), columns=continues)

encoder = OneHotEncoder()
x_train_encoded = encoder.fit_transform(x_train[dispersed]).toarray()
x_train_encoded = pd.DataFrame(x_train_encoded, columns=encoder.get_feature_names_out(dispersed))

x_test_encoded = encoder.fit_transform(x_test[dispersed]).toarray()
x_test_encoded = pd.DataFrame(x_test_encoded, columns=encoder.get_feature_names_out(dispersed))

x_train = pd.concat([x_train[ignored], x_train_continues, x_train_encoded], axis=1)
x_test = pd.concat([x_test[ignored], x_test_continues, x_test_encoded], axis=1)


print(x_train.shape)
print(x_test.shape)
# Out:
# (1000, 119)
# (700, 119)

# %% [markdown]
# 使用MLSMOTE重采样

# %%
# 寻找尾部标签
tail_labels = get_tail_label(y_train)

# 获取尾部标签的索引
indices = get_index(y_train)

# 获取尾部标签的样本
X_sub, y_sub = get_minority_instace(x_train, y_train)

# 应用MLSMOTE来增强数据集
X_resampled, y_resampled = MLSMOTE(X_sub, y_sub, 0)  # 假设生成新样本

# 合并原始数据和生成的数据
X_train_final = pd.concat([x_train, X_resampled], ignore_index=True)
y_train_final = pd.concat([y_train, y_resampled], ignore_index=True)

# 划分出来百分之二十的测试集
X_train, X_valid, Y_train, Y_valid = train_test_split(X_train_final, y_train_final, test_size=0.2, random_state=42)
print(X_train.shape)
print(Y_train.shape)
# Out:
# (1414, 119)
# (1414, 11)

# %% [markdown]
# NN部分

# %%
# 定义模型结构
shared_input = Input(shape=(X_train.shape[1], ), name='shared_input')
shared_layer = Dense(256, activation='relu')(shared_input)
shared_layer = Dense(128, activation='relu')(shared_layer)
shared_layer = Dense(64, activation='relu')(shared_layer)
shared_layer = Dense(32, activation='linear')(shared_layer)

# %% [markdown]
# 定义Specific部分

# %%
outputs = []
for i in range(11):
    task_output = Dense(32,  activation='tanh', name=f'task_{i}_hidden')(shared_layer)
    task_output = Dense(1,  activation='sigmoid', name=f'task_{i}_output')(task_output)
    outputs.append(task_output)
outputs = Concatenate(axis=-1)(outputs)

# %% [markdown]
# 训练模型并输出

# %%
model = Model(inputs=shared_input, outputs=outputs)
# 编译模型，添加精确率和召回率指标
model.compile(
    optimizer='adam',
    loss='binary_crossentropy', #将NN的值传入最终的separate models
    metrics=[
        tf.keras.metrics.Precision(name='precision', thresholds=[0.2, 0.5, 0.7, 0.8, 0.9, 0.95]),
        tf.keras.metrics.Recall(name='recall', thresholds=[0.2, 0.5, 0.7, 0.8, 0.9, 0.95]),
    ])


# 训练模型
history = model.fit(X_train, Y_train, epochs=200, validation_data=(X_valid, Y_valid))
# 计算模型在训练集上的精确率和召回率
train_precision = history.history['precision'] 
train_recall = history.history['recall']

# 计算模型在验证集上的精确率和召回率
val_precision = history.history['val_precision']
val_recall = history.history['val_recall']

# 打印训练集和验证集上的精确率和召回率
print(f'Train Precision: {train_precision[-1]}')
print(f'Train Recall: {train_recall[-1]}')
print(f'Validation Precision: {val_precision[-1]}')
print(f'Validation Recall: {val_recall[-1]}')
# Out:
# Epoch 1/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.6144 - precision: 0.0883 - recall: 0.1642 - val_loss: 0.6051 - val_precision: 0.1329 - val_recall: 0.1536
# Epoch 2/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5683 - precision: 0.1545 - recall: 0.1576 - val_loss: 0.5891 - val_precision: 0.1541 - val_recall: 0.1578
# Epoch 3/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5460 - precision: 0.3619 - recall: 0.1637 - val_loss: 0.5857 - val_precision: 0.2838 - val_recall: 0.1538
# Epoch 4/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5048 - precision: 0.5720 - recall: 0.1868 - val_loss: 0.5810 - val_precision: 0.4901 - val_recall: 0.1498
# Epoch 5/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4522 - precision: 0.7932 - recall: 0.2331 - val_loss: 0.5524 - val_precision: 0.7289 - val_recall: 0.1902
# Epoch 6/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3885 - precision: 0.8574 - recall: 0.2912 - val_loss: 0.5451 - val_precision: 0.7271 - val_recall: 0.2212
# Epoch 7/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3262 - precision: 0.8888 - recall: 0.3815 - val_loss: 0.5115 - val_precision: 0.7482 - val_recall: 0.3261
# Epoch 8/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2693 - precision: 0.9050 - recall: 0.4689 - val_loss: 0.4759 - val_precision: 0.7668 - val_recall: 0.3875
# Epoch 9/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2111 - precision: 0.9251 - recall: 0.5578 - val_loss: 0.4761 - val_precision: 0.7774 - val_recall: 0.4337
# Epoch 10/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1583 - precision: 0.9413 - recall: 0.6602 - val_loss: 0.4602 - val_precision: 0.7839 - val_recall: 0.5148
# Epoch 11/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1142 - precision: 0.9587 - recall: 0.7388 - val_loss: 0.4692 - val_precision: 0.8151 - val_recall: 0.5421
# Epoch 12/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0877 - precision: 0.9712 - recall: 0.7845 - val_loss: 0.4753 - val_precision: 0.8167 - val_recall: 0.5887
# Epoch 13/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0654 - precision: 0.9789 - recall: 0.8453 - val_loss: 0.4581 - val_precision: 0.8341 - val_recall: 0.6422
# Epoch 14/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0451 - precision: 0.9860 - recall: 0.8945 - val_loss: 0.4764 - val_precision: 0.8341 - val_recall: 0.6851
# Epoch 15/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0394 - precision: 0.9886 - recall: 0.9102 - val_loss: 0.4811 - val_precision: 0.8375 - val_recall: 0.7189
# Epoch 16/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0252 - precision: 0.9921 - recall: 0.9433 - val_loss: 0.5023 - val_precision: 0.8394 - val_recall: 0.7361
# Epoch 17/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0185 - precision: 0.9955 - recall: 0.9620 - val_loss: 0.5321 - val_precision: 0.8366 - val_recall: 0.7251
# Epoch 18/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0114 - precision: 0.9980 - recall: 0.9752 - val_loss: 0.5256 - val_precision: 0.8495 - val_recall: 0.7496
# Epoch 19/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0086 - precision: 0.9990 - recall: 0.9845 - val_loss: 0.5422 - val_precision: 0.8451 - val_recall: 0.7595
# Epoch 20/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0052 - precision: 0.9996 - recall: 0.9942 - val_loss: 0.5552 - val_precision: 0.8466 - val_recall: 0.7682
# Epoch 21/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0032 - precision: 1.0000 - recall: 0.9991 - val_loss: 0.5682 - val_precision: 0.8485 - val_recall: 0.7693
# Epoch 22/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0025 - precision: 1.0000 - recall: 0.9996 - val_loss: 0.5774 - val_precision: 0.8482 - val_recall: 0.7690
# Epoch 23/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0020 - precision: 1.0000 - recall: 0.9999 - val_loss: 0.5851 - val_precision: 0.8475 - val_recall: 0.7696
# Epoch 24/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0018 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.5941 - val_precision: 0.8466 - val_recall: 0.7706
# Epoch 25/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0016 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.5996 - val_precision: 0.8451 - val_recall: 0.7709
# Epoch 26/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0014 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6046 - val_precision: 0.8459 - val_recall: 0.7708
# Epoch 27/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0013 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6132 - val_precision: 0.8440 - val_recall: 0.7724
# Epoch 28/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0012 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6178 - val_precision: 0.8446 - val_recall: 0.7712
# Epoch 29/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6241 - val_precision: 0.8447 - val_recall: 0.7716
# Epoch 30/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.9696e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6305 - val_precision: 0.8432 - val_recall: 0.7724
# Epoch 31/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.7197e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6358 - val_precision: 0.8430 - val_recall: 0.7724
# Epoch 32/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.2275e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6405 - val_precision: 0.8435 - val_recall: 0.7724
# Epoch 33/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.7615e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6452 - val_precision: 0.8430 - val_recall: 0.7730
# Epoch 34/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.9500e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6506 - val_precision: 0.8431 - val_recall: 0.7719
# Epoch 35/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.3414e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6546 - val_precision: 0.8423 - val_recall: 0.7724
# Epoch 36/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.1771e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6595 - val_precision: 0.8419 - val_recall: 0.7718
# Epoch 37/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.6210e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6628 - val_precision: 0.8419 - val_recall: 0.7722
# Epoch 38/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3265e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6661 - val_precision: 0.8414 - val_recall: 0.7722
# Epoch 39/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9156e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6703 - val_precision: 0.8421 - val_recall: 0.7718
# Epoch 40/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8293e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6754 - val_precision: 0.8402 - val_recall: 0.7716
# Epoch 41/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5268e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6791 - val_precision: 0.8409 - val_recall: 0.7725
# Epoch 42/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2408e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6821 - val_precision: 0.8415 - val_recall: 0.7725
# Epoch 43/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0239e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6870 - val_precision: 0.8403 - val_recall: 0.7728
# Epoch 44/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8666e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6905 - val_precision: 0.8415 - val_recall: 0.7722
# Epoch 45/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6562e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6937 - val_precision: 0.8410 - val_recall: 0.7730
# Epoch 46/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3757e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6974 - val_precision: 0.8402 - val_recall: 0.7733
# Epoch 47/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2293e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7008 - val_precision: 0.8424 - val_recall: 0.7728
# Epoch 48/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1294e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7039 - val_precision: 0.8415 - val_recall: 0.7728
# Epoch 49/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8583e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7075 - val_precision: 0.8409 - val_recall: 0.7739
# Epoch 50/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7698e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7107 - val_precision: 0.8401 - val_recall: 0.7733
# Epoch 51/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7120e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7138 - val_precision: 0.8406 - val_recall: 0.7739
# Epoch 52/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5560e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7167 - val_precision: 0.8409 - val_recall: 0.7739
# Epoch 53/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4819e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7205 - val_precision: 0.8403 - val_recall: 0.7734
# Epoch 54/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3259e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7233 - val_precision: 0.8408 - val_recall: 0.7742
# Epoch 55/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1675e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7256 - val_precision: 0.8403 - val_recall: 0.7739
# Epoch 56/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1448e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7287 - val_precision: 0.8401 - val_recall: 0.7742
# Epoch 57/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1155e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7324 - val_precision: 0.8405 - val_recall: 0.7740
# Epoch 58/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9896e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7347 - val_precision: 0.8404 - val_recall: 0.7742
# Epoch 59/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8776e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7378 - val_precision: 0.8405 - val_recall: 0.7737
# Epoch 60/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8166e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7403 - val_precision: 0.8400 - val_recall: 0.7739
# Epoch 61/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7024e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7430 - val_precision: 0.8407 - val_recall: 0.7737
# Epoch 62/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6759e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7460 - val_precision: 0.8396 - val_recall: 0.7737
# Epoch 63/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6061e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7484 - val_precision: 0.8400 - val_recall: 0.7737
# Epoch 64/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5578e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7514 - val_precision: 0.8399 - val_recall: 0.7742
# Epoch 65/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4931e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7538 - val_precision: 0.8394 - val_recall: 0.7737
# Epoch 66/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4164e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7561 - val_precision: 0.8393 - val_recall: 0.7740
# Epoch 67/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3620e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7587 - val_precision: 0.8398 - val_recall: 0.7736
# Epoch 68/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3613e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7617 - val_precision: 0.8398 - val_recall: 0.7736
# Epoch 69/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2728e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7638 - val_precision: 0.8390 - val_recall: 0.7739
# Epoch 70/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1869e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7669 - val_precision: 0.8397 - val_recall: 0.7739
# Epoch 71/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2115e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7691 - val_precision: 0.8392 - val_recall: 0.7742
# Epoch 72/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1944e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7716 - val_precision: 0.8391 - val_recall: 0.7742
# Epoch 73/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1168e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7740 - val_precision: 0.8393 - val_recall: 0.7736
# Epoch 74/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0704e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7763 - val_precision: 0.8392 - val_recall: 0.7740
# Epoch 75/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0499e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7790 - val_precision: 0.8396 - val_recall: 0.7742
# Epoch 76/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6332e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7807 - val_precision: 0.8396 - val_recall: 0.7740
# Epoch 77/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5371e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7839 - val_precision: 0.8393 - val_recall: 0.7740
# Epoch 78/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.1960e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7857 - val_precision: 0.8393 - val_recall: 0.7740
# Epoch 79/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.8711e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7879 - val_precision: 0.8387 - val_recall: 0.7743
# Epoch 80/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.6123e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7903 - val_precision: 0.8391 - val_recall: 0.7740
# Epoch 81/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.2135e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7928 - val_precision: 0.8388 - val_recall: 0.7743
# Epoch 82/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.9906e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7952 - val_precision: 0.8390 - val_recall: 0.7740
# Epoch 83/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6637e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7969 - val_precision: 0.8387 - val_recall: 0.7740
# Epoch 84/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.5349e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7994 - val_precision: 0.8394 - val_recall: 0.7740
# Epoch 85/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.3654e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8020 - val_precision: 0.8383 - val_recall: 0.7745
# Epoch 86/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.3053e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8036 - val_precision: 0.8396 - val_recall: 0.7743
# Epoch 87/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.9691e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8061 - val_precision: 0.8386 - val_recall: 0.7743
# Epoch 88/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.6549e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8084 - val_precision: 0.8387 - val_recall: 0.7742
# Epoch 89/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.4168e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8106 - val_precision: 0.8387 - val_recall: 0.7745
# Epoch 90/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.0978e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8132 - val_precision: 0.8374 - val_recall: 0.7745
# Epoch 91/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.0669e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8154 - val_precision: 0.8379 - val_recall: 0.7745
# Epoch 92/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.8112e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8171 - val_precision: 0.8382 - val_recall: 0.7745
# Epoch 93/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5821e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8195 - val_precision: 0.8377 - val_recall: 0.7743
# Epoch 94/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.4634e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8218 - val_precision: 0.8375 - val_recall: 0.7743
# Epoch 95/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2925e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8240 - val_precision: 0.8374 - val_recall: 0.7745
# Epoch 96/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3983e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8260 - val_precision: 0.8374 - val_recall: 0.7745
# Epoch 97/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9671e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8279 - val_precision: 0.8372 - val_recall: 0.7745
# Epoch 98/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9810e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8302 - val_precision: 0.8361 - val_recall: 0.7745
# Epoch 99/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6657e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8317 - val_precision: 0.8378 - val_recall: 0.7745
# Epoch 100/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7105e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8340 - val_precision: 0.8376 - val_recall: 0.7742
# Epoch 101/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3461e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8359 - val_precision: 0.8377 - val_recall: 0.7746
# Epoch 102/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2472e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8380 - val_precision: 0.8373 - val_recall: 0.7742
# Epoch 103/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1487e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8402 - val_precision: 0.8372 - val_recall: 0.7740
# Epoch 104/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1191e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8420 - val_precision: 0.8370 - val_recall: 0.7745
# Epoch 105/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0030e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8441 - val_precision: 0.8370 - val_recall: 0.7743
# Epoch 106/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9476e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8459 - val_precision: 0.8373 - val_recall: 0.7743
# Epoch 107/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7203e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8477 - val_precision: 0.8371 - val_recall: 0.7742
# Epoch 108/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6525e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8496 - val_precision: 0.8368 - val_recall: 0.7742
# Epoch 109/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5526e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8518 - val_precision: 0.8368 - val_recall: 0.7740
# Epoch 110/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4577e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8532 - val_precision: 0.8373 - val_recall: 0.7742
# Epoch 111/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3490e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8558 - val_precision: 0.8369 - val_recall: 0.7740
# Epoch 112/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3045e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8576 - val_precision: 0.8372 - val_recall: 0.7743
# Epoch 113/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1323e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8595 - val_precision: 0.8366 - val_recall: 0.7740
# Epoch 114/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0259e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8615 - val_precision: 0.8361 - val_recall: 0.7742
# Epoch 115/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9751e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8635 - val_precision: 0.8362 - val_recall: 0.7742
# Epoch 116/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8858e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8658 - val_precision: 0.8361 - val_recall: 0.7742
# Epoch 117/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7288e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8672 - val_precision: 0.8365 - val_recall: 0.7742
# Epoch 118/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7138e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8693 - val_precision: 0.8362 - val_recall: 0.7745
# Epoch 119/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6444e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8714 - val_precision: 0.8362 - val_recall: 0.7745
# Epoch 120/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6130e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8729 - val_precision: 0.8359 - val_recall: 0.7746
# Epoch 121/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5409e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8749 - val_precision: 0.8361 - val_recall: 0.7742
# Epoch 122/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4125e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8765 - val_precision: 0.8364 - val_recall: 0.7745
# Epoch 123/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3519e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8788 - val_precision: 0.8357 - val_recall: 0.7745
# Epoch 124/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3600e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8809 - val_precision: 0.8358 - val_recall: 0.7742
# Epoch 125/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.2439e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8823 - val_precision: 0.8365 - val_recall: 0.7746
# Epoch 126/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1439e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8845 - val_precision: 0.8360 - val_recall: 0.7748
# Epoch 127/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0492e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8863 - val_precision: 0.8359 - val_recall: 0.7748
# Epoch 128/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0915e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8883 - val_precision: 0.8353 - val_recall: 0.7745
# Epoch 129/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9957e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8904 - val_precision: 0.8351 - val_recall: 0.7748
# Epoch 130/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9197e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8918 - val_precision: 0.8356 - val_recall: 0.7748
# Epoch 131/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8643e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8942 - val_precision: 0.8348 - val_recall: 0.7746
# Epoch 132/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8361e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8958 - val_precision: 0.8355 - val_recall: 0.7745
# Epoch 133/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8252e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8973 - val_precision: 0.8352 - val_recall: 0.7752
# Epoch 134/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7759e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8999 - val_precision: 0.8351 - val_recall: 0.7748
# Epoch 135/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6825e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9011 - val_precision: 0.8355 - val_recall: 0.7749
# Epoch 136/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6352e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9029 - val_precision: 0.8351 - val_recall: 0.7746
# Epoch 137/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6093e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9048 - val_precision: 0.8354 - val_recall: 0.7749
# Epoch 138/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5762e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9068 - val_precision: 0.8352 - val_recall: 0.7752
# Epoch 139/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5460e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9086 - val_precision: 0.8352 - val_recall: 0.7749
# Epoch 140/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4968e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9102 - val_precision: 0.8352 - val_recall: 0.7752
# Epoch 141/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4724e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9122 - val_precision: 0.8354 - val_recall: 0.7746
# Epoch 142/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4384e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9143 - val_precision: 0.8346 - val_recall: 0.7746
# Epoch 143/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4101e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9158 - val_precision: 0.8348 - val_recall: 0.7749
# Epoch 144/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3360e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9176 - val_precision: 0.8348 - val_recall: 0.7746
# Epoch 145/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2938e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9198 - val_precision: 0.8343 - val_recall: 0.7749
# Epoch 146/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2752e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9217 - val_precision: 0.8340 - val_recall: 0.7749
# Epoch 147/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2761e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9233 - val_precision: 0.8339 - val_recall: 0.7746
# Epoch 148/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2242e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9251 - val_precision: 0.8342 - val_recall: 0.7746
# Epoch 149/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1972e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9270 - val_precision: 0.8336 - val_recall: 0.7749
# Epoch 150/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1833e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9287 - val_precision: 0.8339 - val_recall: 0.7752
# Epoch 151/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1378e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9304 - val_precision: 0.8337 - val_recall: 0.7752
# Epoch 152/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1039e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9323 - val_precision: 0.8339 - val_recall: 0.7752
# Epoch 153/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0632e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9340 - val_precision: 0.8336 - val_recall: 0.7749
# Epoch 154/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0297e-05 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9358 - val_precision: 0.8336 - val_recall: 0.7752
# Epoch 155/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.9993e-06 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9379 - val_precision: 0.8337 - val_recall: 0.7749
# Epoch 156/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.9909e-06 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9392 - val_precision: 0.8338 - val_recall: 0.7749
# Epoch 157/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6998e-06 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9408 - val_precision: 0.8333 - val_recall: 0.7754
# Epoch 158/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.8082e-06 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9428 - val_precision: 0.8332 - val_recall: 0.7752
# Epoch 159/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.1181e-06 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9445 - val_precision: 0.8329 - val_recall: 0.7754
# Epoch 160/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.8401e-06 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9463 - val_precision: 0.8329 - val_recall: 0.7751
# Epoch 161/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.6646e-06 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9481 - val_precision: 0.8333 - val_recall: 0.7754
# Epoch 162/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.5630e-06 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9498 - val_precision: 0.8331 - val_recall: 0.7755
# Epoch 163/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.2422e-06 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9516 - val_precision: 0.8330 - val_recall: 0.7751
# Epoch 164/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.1121e-06 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9535 - val_precision: 0.8330 - val_recall: 0.7751
# Epoch 165/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.0271e-06 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9554 - val_precision: 0.8325 - val_recall: 0.7754
# Epoch 166/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.5662e-06 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9564 - val_precision: 0.8331 - val_recall: 0.7755
# Epoch 167/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.7150e-06 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9584 - val_precision: 0.8326 - val_recall: 0.7752
# Epoch 168/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.1399e-06 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9602 - val_precision: 0.8327 - val_recall: 0.7755
# Epoch 169/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.0824e-06 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9616 - val_precision: 0.8332 - val_recall: 0.7755
# Epoch 170/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.7437e-06 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9639 - val_precision: 0.8324 - val_recall: 0.7755
# Epoch 171/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.8276e-06 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9655 - val_precision: 0.8325 - val_recall: 0.7755
# Epoch 172/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.6735e-06 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9677 - val_precision: 0.8323 - val_recall: 0.7757
# Epoch 173/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.4696e-06 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9689 - val_precision: 0.8327 - val_recall: 0.7755
# Epoch 174/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.4701e-06 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9709 - val_precision: 0.8324 - val_recall: 0.7755
# Epoch 175/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.9747e-06 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9726 - val_precision: 0.8322 - val_recall: 0.7754
# Epoch 176/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.9565e-06 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9743 - val_precision: 0.8322 - val_recall: 0.7751
# Epoch 177/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.8347e-06 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9760 - val_precision: 0.8324 - val_recall: 0.7755
# Epoch 178/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.7678e-06 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9777 - val_precision: 0.8322 - val_recall: 0.7752
# Epoch 179/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.6872e-06 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9795 - val_precision: 0.8325 - val_recall: 0.7754
# Epoch 180/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.4393e-06 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9812 - val_precision: 0.8324 - val_recall: 0.7755
# Epoch 181/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3689e-06 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9828 - val_precision: 0.8324 - val_recall: 0.7757
# Epoch 182/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2499e-06 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9840 - val_precision: 0.8324 - val_recall: 0.7755
# Epoch 183/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0466e-06 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9861 - val_precision: 0.8324 - val_recall: 0.7754
# Epoch 184/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8932e-06 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9880 - val_precision: 0.8320 - val_recall: 0.7751
# Epoch 185/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9276e-06 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9896 - val_precision: 0.8319 - val_recall: 0.7752
# Epoch 186/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6439e-06 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9914 - val_precision: 0.8322 - val_recall: 0.7757
# Epoch 187/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6685e-06 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9931 - val_precision: 0.8319 - val_recall: 0.7752
# Epoch 188/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4975e-06 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9945 - val_precision: 0.8322 - val_recall: 0.7758
# Epoch 189/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4753e-06 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9965 - val_precision: 0.8318 - val_recall: 0.7754
# Epoch 190/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2717e-06 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9982 - val_precision: 0.8321 - val_recall: 0.7755
# Epoch 191/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0796e-06 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.9997 - val_precision: 0.8319 - val_recall: 0.7758
# Epoch 192/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1041e-06 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.0012 - val_precision: 0.8319 - val_recall: 0.7758
# Epoch 193/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9339e-06 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.0029 - val_precision: 0.8326 - val_recall: 0.7754
# Epoch 194/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8970e-06 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.0046 - val_precision: 0.8320 - val_recall: 0.7757
# Epoch 195/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8543e-06 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.0064 - val_precision: 0.8322 - val_recall: 0.7757
# Epoch 196/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7002e-06 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.0077 - val_precision: 0.8325 - val_recall: 0.7754
# Epoch 197/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6930e-06 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.0099 - val_precision: 0.8322 - val_recall: 0.7757
# Epoch 198/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5747e-06 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.0110 - val_precision: 0.8326 - val_recall: 0.7754
# Epoch 199/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4324e-06 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.0129 - val_precision: 0.8318 - val_recall: 0.7757
# Epoch 200/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3557e-06 - precision: 1.0000 - recall: 1.0000 - val_loss: 1.0143 - val_precision: 0.8320 - val_recall: 0.7757
# Train Precision: [1. 1. 1. 1. 1. 1.]
# Train Recall: [1. 1. 1. 1. 1. 1.]
# Validation Precision: [0.8137615  0.8233083  0.8295238  0.83477426 0.8432327  0.847591  ]
# Validation Recall: [0.7891459  0.77935946 0.77491105 0.77313167 0.77046263 0.76690394]

# %%
# 使用模型进行预测
Y_pred = model.predict(X_valid)

# 阈值处理，这里我们将0.5作为分类阈值
Y_pred_binary = (Y_pred > 0.5).astype(int)

# 计算平均精度
average_accuracy = accuracy_score(Y_valid, Y_pred_binary)
print("Average Accuracy:", average_accuracy)

# 计算宏观F1和微观F1
macro_f1 = f1_score(Y_valid, Y_pred_binary, average='macro')
micro_f1 = f1_score(Y_valid, Y_pred_binary, average='micro')
print("Macro F1 Score:", macro_f1)
print("Micro F1 Score:", micro_f1)

# 生成分类报告
report = classification_report(Y_valid, Y_pred_binary, target_names=[f'y_{i}' for i in range(Y_valid.shape[1])], zero_division=0)
print(report)

# 打印训练集和验证集上的最后一个epoch的精确率和召回率
print(f'Train Precision: {train_precision[-1]}')
print(f'Train Recall: {train_recall[-1]}')
print(f'Validation Precision: {val_precision[-1]}')
print(f'Validation Recall: {val_recall[-1]}')


# 使用模型进行预测获取概率输出
Y_pred_proba = model.predict(X_valid)

# 为每个类别绘制ROC曲线和计算AUC
plt.figure(figsize=(10, 8))
for i in range(Y_valid.shape[1]):
    fpr, tpr, _ = roc_curve(Y_valid.iloc[:, i], Y_pred_proba[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f'ROC curve (area = {roc_auc:.2f}) for label {i}')

plt.plot([0, 1], [0, 1], 'k--')  # 绘制对角线
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic for Each Class')
plt.legend(loc="lower right")
plt.show()

# 计算总的微观和宏观平均AUC
micro_auc = roc_auc_score(Y_valid, Y_pred_proba, average="micro")
macro_auc = roc_auc_score(Y_valid, Y_pred_proba, average="macro")
print("Micro-average AUC:", micro_auc)
print("Macro-average AUC:", macro_auc)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Average Accuracy: 0.6779661016949152
# Macro F1 Score: 0.7994803217340798
# Micro F1 Score: 0.8007312614259597
#               precision    recall  f1-score   support
#
#          y_0       0.80      0.69      0.74       102
#          y_1       0.84      0.82      0.83        87
#          y_2       0.90      0.78      0.84       102
#          y_3       0.84      0.86      0.85        98
#          y_4       0.79      0.78      0.79       102
#          y_5       0.77      0.73      0.75        84
#          y_6       0.81      0.77      0.79        96
#          y_7       0.80      0.85      0.83        96
#          y_8       0.79      0.83      0.81       142
#          y_9       0.86      0.75      0.81       110
#         y_10       0.87      0.70      0.77       105
#
#    micro avg       0.82      0.78      0.80      1124
#    macro avg       0.83      0.78      0.80      1124
# weighted avg       0.83      0.78      0.80      1124
#  samples avg       0.76      0.75      0.75      1124
#
# Train Precision: [1. 1. 1. 1. 1. 1.]
# Train Recall: [1. 1. 1. 1. 1. 1.]
# Validation Precision: [0.8137615  0.8233083  0.8295238  0.83477426 0.8432327  0.847591  ]
# Validation Recall: [0.7891459  0.77935946 0.77491105 0.77313167 0.77046263 0.76690394]
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 636us/step
# Micro-average AUC: 0.8862213664452638
# Macro-average AUC: 0.8848411222741099

# %%
# y_hat = model.predict(x_test)

# y_hat = (y_hat > 0.5).astype(int)

# print(y_hat)

# %%
# with open('predict.txt', 'w') as file:
#     for line in y_hat:
#         file.write(str(line)+'\n')
