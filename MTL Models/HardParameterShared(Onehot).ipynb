# %%
import numpy as np
import tensorflow as tf
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Concatenate
from sklearn.preprocessing import StandardScaler, OneHotEncoder
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score,confusion_matrix,f1_score, roc_curve, auc,roc_auc_score
from Include.MLSMOTE import get_tail_label,get_index,get_minority_instace,MLSMOTE
from scipy.stats import yeojohnson

# %% [markdown]
# 找出适合OneHotEncoder的数据
#
# https://zhuanlan.zhihu.com/p/686452650

# %%
# 加载数据
x_train = np.load('../Training data/X_train.npy')  # 特征 (1000, 111)
y_train = np.load('../Training data/y_train.npy')  # 目标 (1000, 11)
x_test=np.load("../Testing data/X_test.npy")


x_train = pd.DataFrame(x_train).rename(columns={i: f"x_{i}" for i in range(111)})
y_train = pd.DataFrame(y_train).rename(columns={i: f"y_{i}" for i in range(11)})
x_test = pd.DataFrame(x_test).rename(columns={i: f"x_{i}" for i in range(111)})

#中位数填补
for column in x_train.columns:
    x_train.fillna({column: x_train[column].median()}, inplace=True)
    x_test.fillna({column: x_test[column].median()}, inplace=True)


# 找出非零值少于1%的列
threshold = 0.02  # 或者任何认为合适的值
cols_to_drop = [col for col in x_train.columns if (x_train[col] != 0).mean() < threshold]
# cols_to_drop += ["x_8",  "x_26", "x_29", "x_30", "x_32", "x_39", "x_50", "x_53", "x_54", "x_64", "x_68", "x_71", "x_93", "x_102"] #补充的一些特殊列
# 删除这些列
x_train.drop(columns=cols_to_drop, inplace=True)
x_test.drop(columns=cols_to_drop, inplace=True)
# Yeo-Johnson 变换
x_train = x_train.apply(lambda x: yeojohnson(x)[0])
x_test = x_test.apply(lambda x: yeojohnson(x)[0])



# 分别分离出适合scaler 和 one hot encode的features
dispersed = []; continues = []; ignored = []
for col in list(x_train.columns):
    col, len(x_train[col].value_counts())
    if 10 > len(x_train[col].value_counts()) > 2:
        dispersed.append(col)
    elif len(x_train[col].value_counts()) >= 10:
        continues.append(col)
    else: ignored.append(col)

# 特征缩放
scaler = StandardScaler()
x_train_continues = pd.DataFrame(scaler.fit_transform(x_train[continues]), columns=continues)
x_test_continues = pd.DataFrame(scaler.fit_transform(x_test[continues]), columns=continues)

encoder = OneHotEncoder()
x_train_encoded = encoder.fit_transform(x_train[dispersed]).toarray()
x_train_encoded = pd.DataFrame(x_train_encoded, columns=encoder.get_feature_names_out(dispersed))

x_test_encoded = encoder.fit_transform(x_test[dispersed]).toarray()
x_test_encoded = pd.DataFrame(x_test_encoded, columns=encoder.get_feature_names_out(dispersed))

x_train = pd.concat([x_train[ignored], x_train_continues, x_train_encoded], axis=1)
x_test = pd.concat([x_test[ignored], x_test_continues, x_test_encoded], axis=1)


print(x_train.shape)
print(x_test.shape)
# Out:
# (1000, 119)
# (700, 119)

# %% [markdown]
# 使用MLSMOTE重采样

# %%
# 寻找尾部标签
tail_labels = get_tail_label(y_train)

# 获取尾部标签的索引
indices = get_index(y_train)

# 获取尾部标签的样本
X_sub, y_sub = get_minority_instace(x_train, y_train)

# 应用MLSMOTE来增强数据集
X_resampled, y_resampled = MLSMOTE(X_sub, y_sub, 0)  # 假设生成新样本

# 合并原始数据和生成的数据
X_train_final = pd.concat([x_train, X_resampled], ignore_index=True)
y_train_final = pd.concat([y_train, y_resampled], ignore_index=True)

# 划分出来百分之二十的测试集
X_train, X_valid, Y_train, Y_valid = train_test_split(X_train_final, y_train_final, test_size=0.2, random_state=42)
print(X_train.shape)
print(Y_train.shape)
# Out:
# (1414, 119)
# (1414, 11)

# %% [markdown]
# NN部分

# %%
# 定义模型结构
shared_input = Input(shape=(X_train.shape[1], ), name='shared_input')
shared_layer = Dense(128, activation='relu')(shared_input)
shared_layer = Dense(128, activation='relu')(shared_layer)
shared_layer = Dense(64, activation='relu')(shared_layer)
shared_layer = Dense(32, activation='relu')(shared_layer)

# %% [markdown]
# 定义Specific部分

# %%
outputs = []
for i in range(11):
    task_output = Dense(32,  activation='tanh', name=f'task_{i}_hidden')(shared_layer)
    task_output = Dense(1,  activation='sigmoid', name=f'task_{i}_output')(task_output)
    outputs.append(task_output)
outputs = Concatenate(axis=-1)(outputs)

# %% [markdown]
# 训练模型并输出

# %%
model = Model(inputs=shared_input, outputs=outputs)
# 编译模型，添加精确率和召回率指标
model.compile(
    optimizer='adam',
    loss='binary_crossentropy', #将NN的值传入最终的separate models
    metrics=[
        tf.keras.metrics.Precision(name='precision', thresholds=[0.2, 0.5, 0.7, 0.8, 0.9, 0.95]),
        tf.keras.metrics.Recall(name='recall', thresholds=[0.2, 0.5, 0.7, 0.8, 0.9, 0.95]),
    ])


# 训练模型
history = model.fit(X_train, Y_train, epochs=50, validation_data=(X_valid, Y_valid))
# Out:
# Epoch 1/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.6221 - precision: 0.0913 - recall: 0.1692 - val_loss: 0.6113 - val_precision: 0.0500 - val_recall: 0.1455
# Epoch 2/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5708 - precision: 0.0702 - recall: 0.1498 - val_loss: 0.6051 - val_precision: 0.2161 - val_recall: 0.1578
# Epoch 3/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5602 - precision: 0.1566 - recall: 0.1599 - val_loss: 0.5979 - val_precision: 0.1707 - val_recall: 0.1455
# Epoch 4/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5397 - precision: 0.3049 - recall: 0.1585 - val_loss: 0.5946 - val_precision: 0.1623 - val_recall: 0.1437
# Epoch 5/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5049 - precision: 0.4088 - recall: 0.1722 - val_loss: 0.5779 - val_precision: 0.2762 - val_recall: 0.1548
# Epoch 6/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4739 - precision: 0.5682 - recall: 0.2008 - val_loss: 0.5756 - val_precision: 0.6130 - val_recall: 0.1825
# Epoch 7/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4242 - precision: 0.7860 - recall: 0.2527 - val_loss: 0.5635 - val_precision: 0.7596 - val_recall: 0.2119
# Epoch 8/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3774 - precision: 0.8620 - recall: 0.3084 - val_loss: 0.5610 - val_precision: 0.7549 - val_recall: 0.2329
# Epoch 9/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3388 - precision: 0.8753 - recall: 0.3486 - val_loss: 0.5549 - val_precision: 0.7118 - val_recall: 0.2800
# Epoch 10/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2897 - precision: 0.9000 - recall: 0.4258 - val_loss: 0.5440 - val_precision: 0.7088 - val_recall: 0.3169
# Epoch 11/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2469 - precision: 0.9133 - recall: 0.4877 - val_loss: 0.5395 - val_precision: 0.7479 - val_recall: 0.3422
# Epoch 12/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2119 - precision: 0.9263 - recall: 0.5552 - val_loss: 0.5310 - val_precision: 0.7456 - val_recall: 0.4073
# Epoch 13/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1686 - precision: 0.9395 - recall: 0.6300 - val_loss: 0.5126 - val_precision: 0.7740 - val_recall: 0.4356
# Epoch 14/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1476 - precision: 0.9505 - recall: 0.6626 - val_loss: 0.5164 - val_precision: 0.7711 - val_recall: 0.4976
# Epoch 15/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1186 - precision: 0.9611 - recall: 0.7211 - val_loss: 0.5111 - val_precision: 0.7739 - val_recall: 0.5056
# Epoch 16/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0937 - precision: 0.9706 - recall: 0.7750 - val_loss: 0.5125 - val_precision: 0.7878 - val_recall: 0.5627
# Epoch 17/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0783 - precision: 0.9767 - recall: 0.8063 - val_loss: 0.5120 - val_precision: 0.8069 - val_recall: 0.5839
# Epoch 18/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0583 - precision: 0.9833 - recall: 0.8506 - val_loss: 0.5222 - val_precision: 0.7968 - val_recall: 0.6435
# Epoch 19/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0504 - precision: 0.9825 - recall: 0.8756 - val_loss: 0.5200 - val_precision: 0.8129 - val_recall: 0.6490
# Epoch 20/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0355 - precision: 0.9907 - recall: 0.9062 - val_loss: 0.5429 - val_precision: 0.8128 - val_recall: 0.6504
# Epoch 21/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0312 - precision: 0.9928 - recall: 0.9192 - val_loss: 0.5575 - val_precision: 0.8068 - val_recall: 0.7131
# Epoch 22/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0245 - precision: 0.9936 - recall: 0.9463 - val_loss: 0.5683 - val_precision: 0.8184 - val_recall: 0.7220
# Epoch 23/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0165 - precision: 0.9974 - recall: 0.9636 - val_loss: 0.5811 - val_precision: 0.8199 - val_recall: 0.7344
# Epoch 24/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0126 - precision: 0.9992 - recall: 0.9721 - val_loss: 0.6142 - val_precision: 0.8143 - val_recall: 0.7448
# Epoch 25/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0085 - precision: 0.9994 - recall: 0.9845 - val_loss: 0.6147 - val_precision: 0.8209 - val_recall: 0.7653
# Epoch 26/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0069 - precision: 0.9996 - recall: 0.9902 - val_loss: 0.6355 - val_precision: 0.8167 - val_recall: 0.7617
# Epoch 27/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0060 - precision: 0.9997 - recall: 0.9918 - val_loss: 0.6429 - val_precision: 0.8227 - val_recall: 0.7672
# Epoch 28/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0047 - precision: 0.9999 - recall: 0.9954 - val_loss: 0.6603 - val_precision: 0.8186 - val_recall: 0.7719
# Epoch 29/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0039 - precision: 1.0000 - recall: 0.9968 - val_loss: 0.6699 - val_precision: 0.8201 - val_recall: 0.7754
# Epoch 30/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0032 - precision: 1.0000 - recall: 0.9982 - val_loss: 0.6742 - val_precision: 0.8206 - val_recall: 0.7783
# Epoch 31/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0028 - precision: 1.0000 - recall: 0.9989 - val_loss: 0.6885 - val_precision: 0.8174 - val_recall: 0.7789
# Epoch 32/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0024 - precision: 1.0000 - recall: 0.9997 - val_loss: 0.6958 - val_precision: 0.8186 - val_recall: 0.7777
# Epoch 33/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0022 - precision: 1.0000 - recall: 0.9998 - val_loss: 0.7040 - val_precision: 0.8166 - val_recall: 0.7789
# Epoch 34/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0021 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7114 - val_precision: 0.8174 - val_recall: 0.7789
# Epoch 35/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0018 - precision: 1.0000 - recall: 0.9999 - val_loss: 0.7204 - val_precision: 0.8150 - val_recall: 0.7794
# Epoch 36/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0017 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7250 - val_precision: 0.8172 - val_recall: 0.7801
# Epoch 37/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0016 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7346 - val_precision: 0.8159 - val_recall: 0.7795
# Epoch 38/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0015 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7393 - val_precision: 0.8168 - val_recall: 0.7795
# Epoch 39/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0013 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7477 - val_precision: 0.8151 - val_recall: 0.7792
# Epoch 40/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0012 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7523 - val_precision: 0.8147 - val_recall: 0.7798
# Epoch 41/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7597 - val_precision: 0.8141 - val_recall: 0.7798
# Epoch 42/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0010 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7661 - val_precision: 0.8140 - val_recall: 0.7802
# Epoch 43/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5891e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7713 - val_precision: 0.8122 - val_recall: 0.7804
# Epoch 44/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.3118e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7772 - val_precision: 0.8129 - val_recall: 0.7807
# Epoch 45/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.5622e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7823 - val_precision: 0.8115 - val_recall: 0.7807
# Epoch 46/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.6940e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7880 - val_precision: 0.8123 - val_recall: 0.7814
# Epoch 47/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.1450e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7915 - val_precision: 0.8127 - val_recall: 0.7805
# Epoch 48/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.0483e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7972 - val_precision: 0.8140 - val_recall: 0.7802
# Epoch 49/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.5621e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8012 - val_precision: 0.8121 - val_recall: 0.7810
# Epoch 50/50
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.2224e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.8082 - val_precision: 0.8104 - val_recall: 0.7810

# %%
# 计算模型在训练集上的精确率和召回率
train_precision = history.history['precision'] 
train_recall = history.history['recall']
train_loss = history.history['loss']

# 计算模型在验证集上的精确率和召回率
val_precision = history.history['val_precision']
val_recall = history.history['val_recall']
val_loss = history.history['val_loss']

# 打印训练集和验证集上的精确率和召回率
print(f'Train Precision: {train_precision[-1]}')
print(f'Validation Precision: {val_precision[-1]}')

print(f'Train Recall: {train_recall[-1]}')
print(f'Validation Recall: {val_recall[-1]}')

print(f'Train Loss: {train_loss[-1]}')
print(f'Validation Loss: {val_loss[-1]}')
# Out:
# Train Precision: [1. 1. 1. 1. 1. 1.]
# Validation Precision: [0.7592905  0.7917415  0.8123845  0.8208255  0.83237547 0.84607846]
# Train Recall: [1. 1. 1. 1. 1. 1.]
# Validation Recall: [0.7998221  0.78469753 0.7820285  0.77846974 0.77313167 0.7677936 ]
# Train Loss: 0.0006367520545609295
# Validation Loss: 0.8082498908042908

# %%
# 使用模型进行预测
Y_pred = model.predict(X_valid)

# 阈值处理，这里我们将0.5作为分类阈值
Y_pred_binary = (Y_pred > 0.5).astype(int)

# 计算平均精度
average_accuracy = accuracy_score(Y_valid, Y_pred_binary)
print("Average Accuracy:", average_accuracy)

# 计算宏观F1和微观F1
macro_f1 = f1_score(Y_valid, Y_pred_binary, average='macro')
micro_f1 = f1_score(Y_valid, Y_pred_binary, average='micro')
print("Macro F1 Score:", macro_f1)
print("Micro F1 Score:", micro_f1)

# 生成分类报告
report = classification_report(Y_valid, Y_pred_binary, target_names=[f'y_{i}' for i in range(Y_valid.shape[1])], zero_division=0)
print(report)

# 打印训练集和验证集上的最后一个epoch的精确率和召回率
print(f'Train Precision: {train_precision[-1]}')
print(f'Train Recall: {train_recall[-1]}')
print(f'Validation Precision: {val_precision[-1]}')
print(f'Validation Recall: {val_recall[-1]}')


# 使用模型进行预测获取概率输出
Y_pred_proba = model.predict(X_valid)

# 为每个类别绘制ROC曲线和计算AUC
plt.figure(figsize=(10, 8))
for i in range(Y_valid.shape[1]):
    fpr, tpr, _ = roc_curve(Y_valid.iloc[:, i], Y_pred_proba[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f'ROC curve (area = {roc_auc:.2f}) for label {i}')

plt.plot([0, 1], [0, 1], 'k--')  # 绘制对角线
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic for Each Class')
plt.legend(loc="lower right")
plt.show()

# 计算总的微观和宏观平均AUC
micro_auc = roc_auc_score(Y_valid, Y_pred_proba, average="micro")
macro_auc = roc_auc_score(Y_valid, Y_pred_proba, average="macro")
print("Micro-average AUC:", micro_auc)
print("Macro-average AUC:", macro_auc)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Average Accuracy: 0.6751412429378532
# Macro F1 Score: 0.785371844904547
# Micro F1 Score: 0.7882037533512064
#               precision    recall  f1-score   support
#
#          y_0       0.79      0.70      0.74       102
#          y_1       0.86      0.79      0.83        87
#          y_2       0.86      0.82      0.84       102
#          y_3       0.72      0.84      0.77        98
#          y_4       0.77      0.82      0.80       102
#          y_5       0.76      0.70      0.73        84
#          y_6       0.80      0.75      0.77        96
#          y_7       0.75      0.85      0.80        96
#          y_8       0.80      0.87      0.84       142
#          y_9       0.85      0.75      0.79       110
#         y_10       0.78      0.70      0.74       105
#
#    micro avg       0.79      0.78      0.79      1124
#    macro avg       0.79      0.78      0.79      1124
# weighted avg       0.79      0.78      0.79      1124
#  samples avg       0.75      0.75      0.74      1124
#
# Train Precision: [1. 1. 1. 1. 1. 1.]
# Train Recall: [1. 1. 1. 1. 1. 1.]
# Validation Precision: [0.7592905  0.7917415  0.8123845  0.8208255  0.83237547 0.84607846]
# Validation Recall: [0.7998221  0.78469753 0.7820285  0.77846974 0.77313167 0.7677936 ]
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step
# Micro-average AUC: 0.8694372534912702
# Macro-average AUC: 0.8663461234895761

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 将预测概率转换为DataFrame
probabilities_df = pd.DataFrame(Y_pred_proba, columns=[f'Label_{i}' for i in range(Y_pred_proba.shape[1])])

# 将预测概率DataFrame与特征DataFrame合并
# 假设 X_valid 是特征数据
combined_df = pd.concat([X_valid.reset_index(drop=True), probabilities_df], axis=1)

# 计算特征与预测概率之间的相关矩阵
correlation_matrix = combined_df.corr()

# 提取与标签相关的相关性部分
labels_correlation = correlation_matrix.loc[:, probabilities_df.columns].iloc[:-len(probabilities_df.columns), :]

# 使用Seaborn绘制热力图
plt.figure(figsize=(16, 10))
sns.heatmap(labels_correlation, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Heatmap of Features and Predicted Label Probabilities Correlation')
plt.xlabel('Predicted Labels')
plt.ylabel('Features')
plt.show()

# %%
# y_hat = model.predict(x_test)

# y_hat = (y_hat > 0.5).astype(int)

# print(y_hat)

# %%
# with open('predict.txt', 'w') as file:
#     for line in y_hat:
#         file.write(str(line)+'\n')
