# %%
import numpy as np
import tensorflow as tf
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Concatenate
from sklearn.preprocessing import StandardScaler, OneHotEncoder
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score,confusion_matrix,f1_score, roc_curve, auc,roc_auc_score
from MLSMOTE import get_tail_label,get_index,get_minority_instace,MLSMOTE
from scipy.stats import yeojohnson

# %% [markdown]
# 找出适合OneHotEncoder的数据
#
# https://zhuanlan.zhihu.com/p/686452650

# %%
# 加载数据
x_train = np.load('../Training data/X_train.npy')  # 特征 (1000, 111)
y_train = np.load('../Training data/y_train.npy')  # 目标 (1000, 11)
x_test=np.load("../Testing data/X_test.npy")


x_train = pd.DataFrame(x_train).rename(columns={i: f"x_{i}" for i in range(111)})
y_train = pd.DataFrame(y_train).rename(columns={i: f"y_{i}" for i in range(11)})
x_test = pd.DataFrame(x_test).rename(columns={i: f"x_{i}" for i in range(111)})

#中位数填补
for column in x_train.columns:
    x_train.fillna({column: x_train[column].median()}, inplace=True)
    x_test.fillna({column: x_test[column].median()}, inplace=True)


# 找出非零值少于1%的列
threshold = 0.01  # 或者任何认为合适的值
cols_to_drop = [col for col in x_train.columns if (x_train[col] != 0).mean() < threshold]
# cols_to_drop += ["x_8",  "x_26", "x_29", "x_30", "x_32", "x_39", "x_50", "x_53", "x_54", "x_64", "x_68", "x_71", "x_93", "x_102"] #补充的一些特殊列
# 删除这些列
x_train.drop(columns=cols_to_drop, inplace=True)
x_test.drop(columns=cols_to_drop, inplace=True)

# Yeo-Johnson 变换
x_train = x_train.apply(lambda x: yeojohnson(x)[0])
x_test = x_test.apply(lambda x: yeojohnson(x)[0])



# 分别分离出适合scaler 和 one hot encode的features
dispersed = []; continues = []
for col in list(x_train.columns):
    col, len(x_train[col].value_counts())
    if 10 >= len(x_train[col].value_counts()) > 2:
        dispersed.append(col)
    else:
        continues.append(col)


# 特征缩放
scaler = StandardScaler()
x_train_continues = pd.DataFrame(scaler.fit_transform(x_train[continues]), columns=continues)
x_test_continues = pd.DataFrame(scaler.fit_transform(x_test[continues]), columns=continues)

encoder = OneHotEncoder()
x_train_encoded = encoder.fit_transform(x_train[dispersed]).toarray()
x_train_encoded = pd.DataFrame(x_train_encoded, columns=encoder.get_feature_names_out(dispersed))

x_test_encoded = encoder.fit_transform(x_test[dispersed]).toarray()
x_test_encoded = pd.DataFrame(x_test_encoded, columns=encoder.get_feature_names_out(dispersed))

x_train = pd.concat([x_train_continues, x_train_encoded], axis=1)
x_test = pd.concat([ x_test_continues, x_test_encoded], axis=1)


print(x_train.shape)
print(x_test.shape)
# Out:
# (1000, 148)
# (700, 148)

# %% [markdown]
# 使用MLSMOTE重采样

# %%
# 寻找尾部标签
tail_labels = get_tail_label(y_train)

# 获取尾部标签的索引
indices = get_index(y_train)

# 获取尾部标签的样本
X_sub, y_sub = get_minority_instace(x_train, y_train)

# 应用MLSMOTE来增强数据集
X_resampled, y_resampled = MLSMOTE(X_sub, y_sub, 0)  # 假设生成新样本

# 合并原始数据和生成的数据
X_train_final = pd.concat([x_train, X_resampled], ignore_index=True)
y_train_final = pd.concat([y_train, y_resampled], ignore_index=True)

# 划分出来百分之二十的测试集
X_train, X_valid, Y_train, Y_valid = train_test_split(X_train_final, y_train_final, test_size=0.2, random_state=42)
print(X_train.shape)
print(Y_train.shape)
# Out:
# (1414, 148)
# (1414, 11)

# %% [markdown]
# NN部分

# %%
# 定义模型结构
shared_input = Input(shape=(X_train.shape[1], ), name='shared_input')
shared_layer = Dense(256, activation='relu')(shared_input)
shared_layer = Dense(128, activation='relu')(shared_layer)
shared_layer = Dense(64, activation='relu')(shared_layer)
shared_layer = Dense(32, activation='tanh')(shared_layer)
outputs      = Dense(11, activation='sigmoid')(shared_layer)

# %% [markdown]
# 训练模型并输出

# %%
model = Model(inputs=shared_input, outputs=outputs)
# 编译模型，添加精确率和召回率指标
model.compile(
    optimizer='adam',
    loss='binary_crossentropy', #将NN的值传入最终的separate models
    metrics=[
        tf.keras.metrics.Precision(name='precision', thresholds=[0.2, 0.5, 0.7, 0.8, 0.9, 0.95]),
        tf.keras.metrics.Recall(name='recall', thresholds=[0.2, 0.5, 0.7, 0.8, 0.9, 0.95]),
    ])


# 训练模型
history = model.fit(X_train, Y_train, epochs=200, validation_data=(X_valid, Y_valid))
# 计算模型在训练集上的精确率和召回率
train_precision = history.history['precision'] 
train_recall = history.history['recall']

# 计算模型在验证集上的精确率和召回率
val_precision = history.history['val_precision']
val_recall = history.history['val_recall']

# 打印训练集和验证集上的精确率和召回率
print(f'Train Precision: {train_precision[-1]}')
print(f'Train Recall: {train_recall[-1]}')
print(f'Validation Precision: {val_precision[-1]}')
print(f'Validation Recall: {val_recall[-1]}')
# Out:
# Epoch 1/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.6163 - precision: 0.0980 - recall: 0.1769 - val_loss: 0.6051 - val_precision: 0.0501 - val_recall: 0.1481
# Epoch 2/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5598 - precision: 0.1470 - recall: 0.1595 - val_loss: 0.5966 - val_precision: 0.2051 - val_recall: 0.1509
# Epoch 3/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5275 - precision: 0.2608 - recall: 0.1655 - val_loss: 0.5826 - val_precision: 0.2945 - val_recall: 0.1595
# Epoch 4/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4994 - precision: 0.4912 - recall: 0.1879 - val_loss: 0.5664 - val_precision: 0.2955 - val_recall: 0.1572
# Epoch 5/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4533 - precision: 0.5874 - recall: 0.2125 - val_loss: 0.5407 - val_precision: 0.4885 - val_recall: 0.1874
# Epoch 6/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4013 - precision: 0.7150 - recall: 0.2595 - val_loss: 0.5240 - val_precision: 0.8090 - val_recall: 0.2002
# Epoch 7/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3652 - precision: 0.7767 - recall: 0.3060 - val_loss: 0.4997 - val_precision: 0.8129 - val_recall: 0.2238
# Epoch 8/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3199 - precision: 0.8901 - recall: 0.3606 - val_loss: 0.4717 - val_precision: 0.7994 - val_recall: 0.2948
# Epoch 9/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2889 - precision: 0.9049 - recall: 0.4085 - val_loss: 0.4519 - val_precision: 0.8049 - val_recall: 0.3187
# Epoch 10/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2512 - precision: 0.9198 - recall: 0.4469 - val_loss: 0.4361 - val_precision: 0.8037 - val_recall: 0.3485
# Epoch 11/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2188 - precision: 0.9281 - recall: 0.4956 - val_loss: 0.4287 - val_precision: 0.7965 - val_recall: 0.3614
# Epoch 12/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1909 - precision: 0.9395 - recall: 0.5356 - val_loss: 0.4185 - val_precision: 0.8046 - val_recall: 0.3919
# Epoch 13/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1657 - precision: 0.9494 - recall: 0.5796 - val_loss: 0.4105 - val_precision: 0.7970 - val_recall: 0.4266
# Epoch 14/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1461 - precision: 0.9578 - recall: 0.6195 - val_loss: 0.4037 - val_precision: 0.7953 - val_recall: 0.4607
# Epoch 15/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1256 - precision: 0.9657 - recall: 0.6581 - val_loss: 0.3992 - val_precision: 0.8182 - val_recall: 0.4764
# Epoch 16/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1134 - precision: 0.9720 - recall: 0.6895 - val_loss: 0.3845 - val_precision: 0.8246 - val_recall: 0.4797
# Epoch 17/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1011 - precision: 0.9772 - recall: 0.7092 - val_loss: 0.3987 - val_precision: 0.8042 - val_recall: 0.5388
# Epoch 18/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0909 - precision: 0.9798 - recall: 0.7414 - val_loss: 0.3890 - val_precision: 0.8247 - val_recall: 0.5289
# Epoch 19/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0804 - precision: 0.9859 - recall: 0.7655 - val_loss: 0.3940 - val_precision: 0.8254 - val_recall: 0.5577
# Epoch 20/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0728 - precision: 0.9878 - recall: 0.7875 - val_loss: 0.3951 - val_precision: 0.8302 - val_recall: 0.5608
# Epoch 21/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0671 - precision: 0.9904 - recall: 0.8053 - val_loss: 0.3945 - val_precision: 0.8368 - val_recall: 0.5737
# Epoch 22/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0596 - precision: 0.9925 - recall: 0.8210 - val_loss: 0.4011 - val_precision: 0.8311 - val_recall: 0.6093
# Epoch 23/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0554 - precision: 0.9932 - recall: 0.8452 - val_loss: 0.4089 - val_precision: 0.8307 - val_recall: 0.6210
# Epoch 24/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0519 - precision: 0.9936 - recall: 0.8549 - val_loss: 0.4029 - val_precision: 0.8371 - val_recall: 0.6333
# Epoch 25/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0484 - precision: 0.9939 - recall: 0.8681 - val_loss: 0.4056 - val_precision: 0.8383 - val_recall: 0.6465
# Epoch 26/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0433 - precision: 0.9964 - recall: 0.8882 - val_loss: 0.4091 - val_precision: 0.8477 - val_recall: 0.6366
# Epoch 27/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0407 - precision: 0.9972 - recall: 0.8932 - val_loss: 0.4145 - val_precision: 0.8394 - val_recall: 0.6659
# Epoch 28/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0368 - precision: 0.9977 - recall: 0.9092 - val_loss: 0.4142 - val_precision: 0.8537 - val_recall: 0.6538
# Epoch 29/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0361 - precision: 0.9976 - recall: 0.9082 - val_loss: 0.4083 - val_precision: 0.8458 - val_recall: 0.6883
# Epoch 30/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0322 - precision: 0.9981 - recall: 0.9249 - val_loss: 0.4158 - val_precision: 0.8560 - val_recall: 0.6658
# Epoch 31/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0302 - precision: 0.9984 - recall: 0.9328 - val_loss: 0.4237 - val_precision: 0.8459 - val_recall: 0.6919
# Epoch 32/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0276 - precision: 0.9984 - recall: 0.9452 - val_loss: 0.4201 - val_precision: 0.8413 - val_recall: 0.7009
# Epoch 33/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0268 - precision: 0.9986 - recall: 0.9454 - val_loss: 0.4286 - val_precision: 0.8431 - val_recall: 0.7054
# Epoch 34/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0258 - precision: 0.9991 - recall: 0.9508 - val_loss: 0.4290 - val_precision: 0.8483 - val_recall: 0.6916
# Epoch 35/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0237 - precision: 0.9992 - recall: 0.9561 - val_loss: 0.4284 - val_precision: 0.8476 - val_recall: 0.7113
# Epoch 36/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0219 - precision: 0.9993 - recall: 0.9629 - val_loss: 0.4364 - val_precision: 0.8445 - val_recall: 0.7260
# Epoch 37/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0201 - precision: 0.9995 - recall: 0.9692 - val_loss: 0.4474 - val_precision: 0.8364 - val_recall: 0.7380
# Epoch 38/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0260 - precision: 0.9971 - recall: 0.9543 - val_loss: 0.4515 - val_precision: 0.8426 - val_recall: 0.6957
# Epoch 39/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0246 - precision: 0.9975 - recall: 0.9532 - val_loss: 0.4454 - val_precision: 0.8348 - val_recall: 0.7074
# Epoch 40/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0245 - precision: 0.9985 - recall: 0.9489 - val_loss: 0.4534 - val_precision: 0.8307 - val_recall: 0.7206
# Epoch 41/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0203 - precision: 0.9988 - recall: 0.9633 - val_loss: 0.4511 - val_precision: 0.8448 - val_recall: 0.7230
# Epoch 42/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0169 - precision: 0.9997 - recall: 0.9748 - val_loss: 0.4581 - val_precision: 0.8412 - val_recall: 0.7297
# Epoch 43/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0167 - precision: 0.9996 - recall: 0.9755 - val_loss: 0.4608 - val_precision: 0.8457 - val_recall: 0.7349
# Epoch 44/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0150 - precision: 0.9997 - recall: 0.9831 - val_loss: 0.4598 - val_precision: 0.8439 - val_recall: 0.7392
# Epoch 45/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0137 - precision: 0.9994 - recall: 0.9876 - val_loss: 0.4699 - val_precision: 0.8387 - val_recall: 0.7469
# Epoch 46/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0149 - precision: 0.9992 - recall: 0.9885 - val_loss: 0.4733 - val_precision: 0.8464 - val_recall: 0.7364
# Epoch 47/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0134 - precision: 0.9995 - recall: 0.9877 - val_loss: 0.4780 - val_precision: 0.8361 - val_recall: 0.7438
# Epoch 48/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0146 - precision: 0.9992 - recall: 0.9824 - val_loss: 0.4816 - val_precision: 0.8337 - val_recall: 0.7350
# Epoch 49/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0128 - precision: 0.9996 - recall: 0.9856 - val_loss: 0.4804 - val_precision: 0.8421 - val_recall: 0.7494
# Epoch 50/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0117 - precision: 0.9992 - recall: 0.9910 - val_loss: 0.4855 - val_precision: 0.8423 - val_recall: 0.7464
# Epoch 51/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0103 - precision: 0.9996 - recall: 0.9937 - val_loss: 0.4863 - val_precision: 0.8452 - val_recall: 0.7476
# Epoch 52/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0095 - precision: 0.9998 - recall: 0.9965 - val_loss: 0.4926 - val_precision: 0.8411 - val_recall: 0.7519
# Epoch 53/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0089 - precision: 0.9999 - recall: 0.9966 - val_loss: 0.4930 - val_precision: 0.8451 - val_recall: 0.7493
# Epoch 54/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0087 - precision: 0.9999 - recall: 0.9979 - val_loss: 0.4901 - val_precision: 0.8432 - val_recall: 0.7531
# Epoch 55/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0085 - precision: 1.0000 - recall: 0.9967 - val_loss: 0.4969 - val_precision: 0.8454 - val_recall: 0.7504
# Epoch 56/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0079 - precision: 0.9999 - recall: 0.9971 - val_loss: 0.4969 - val_precision: 0.8404 - val_recall: 0.7522
# Epoch 57/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0076 - precision: 0.9999 - recall: 0.9977 - val_loss: 0.4996 - val_precision: 0.8413 - val_recall: 0.7533
# Epoch 58/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0070 - precision: 1.0000 - recall: 0.9986 - val_loss: 0.5045 - val_precision: 0.8405 - val_recall: 0.7534
# Epoch 59/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0068 - precision: 1.0000 - recall: 0.9990 - val_loss: 0.5077 - val_precision: 0.8426 - val_recall: 0.7533
# Epoch 60/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0066 - precision: 1.0000 - recall: 0.9991 - val_loss: 0.5098 - val_precision: 0.8388 - val_recall: 0.7537
# Epoch 61/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0064 - precision: 1.0000 - recall: 0.9989 - val_loss: 0.5142 - val_precision: 0.8412 - val_recall: 0.7540
# Epoch 62/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0060 - precision: 1.0000 - recall: 0.9992 - val_loss: 0.5179 - val_precision: 0.8368 - val_recall: 0.7521
# Epoch 63/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0060 - precision: 0.9999 - recall: 0.9994 - val_loss: 0.5135 - val_precision: 0.8431 - val_recall: 0.7522
# Epoch 64/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0061 - precision: 1.0000 - recall: 0.9984 - val_loss: 0.5190 - val_precision: 0.8386 - val_recall: 0.7531
# Epoch 65/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0056 - precision: 1.0000 - recall: 0.9994 - val_loss: 0.5259 - val_precision: 0.8392 - val_recall: 0.7540
# Epoch 66/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0056 - precision: 0.9999 - recall: 0.9991 - val_loss: 0.5315 - val_precision: 0.8370 - val_recall: 0.7544
# Epoch 67/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0057 - precision: 0.9998 - recall: 0.9992 - val_loss: 0.5369 - val_precision: 0.8330 - val_recall: 0.7539
# Epoch 68/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0055 - precision: 1.0000 - recall: 0.9986 - val_loss: 0.5379 - val_precision: 0.8355 - val_recall: 0.7561
# Epoch 69/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0055 - precision: 0.9999 - recall: 0.9987 - val_loss: 0.5377 - val_precision: 0.8391 - val_recall: 0.7527
# Epoch 70/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0060 - precision: 0.9997 - recall: 0.9967 - val_loss: 0.5419 - val_precision: 0.8269 - val_recall: 0.7487
# Epoch 71/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0196 - precision: 0.9938 - recall: 0.9689 - val_loss: 0.6885 - val_precision: 0.7627 - val_recall: 0.5676
# Epoch 72/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1389 - precision: 0.9345 - recall: 0.7972 - val_loss: 0.6273 - val_precision: 0.7581 - val_recall: 0.6068
# Epoch 73/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1171 - precision: 0.9430 - recall: 0.8318 - val_loss: 0.5623 - val_precision: 0.7749 - val_recall: 0.6908
# Epoch 74/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0501 - precision: 0.9799 - recall: 0.9050 - val_loss: 0.5263 - val_precision: 0.8383 - val_recall: 0.6750
# Epoch 75/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0229 - precision: 0.9960 - recall: 0.9478 - val_loss: 0.5405 - val_precision: 0.8264 - val_recall: 0.7312
# Epoch 76/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0123 - precision: 0.9995 - recall: 0.9795 - val_loss: 0.5317 - val_precision: 0.8353 - val_recall: 0.7516
# Epoch 77/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0089 - precision: 1.0000 - recall: 0.9910 - val_loss: 0.5333 - val_precision: 0.8366 - val_recall: 0.7579
# Epoch 78/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0075 - precision: 1.0000 - recall: 0.9962 - val_loss: 0.5358 - val_precision: 0.8403 - val_recall: 0.7586
# Epoch 79/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0070 - precision: 1.0000 - recall: 0.9971 - val_loss: 0.5390 - val_precision: 0.8389 - val_recall: 0.7608
# Epoch 80/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0064 - precision: 1.0000 - recall: 0.9985 - val_loss: 0.5407 - val_precision: 0.8375 - val_recall: 0.7641
# Epoch 81/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0060 - precision: 1.0000 - recall: 0.9987 - val_loss: 0.5431 - val_precision: 0.8395 - val_recall: 0.7633
# Epoch 82/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0056 - precision: 1.0000 - recall: 0.9989 - val_loss: 0.5459 - val_precision: 0.8374 - val_recall: 0.7638
# Epoch 83/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0053 - precision: 1.0000 - recall: 0.9987 - val_loss: 0.5484 - val_precision: 0.8372 - val_recall: 0.7632
# Epoch 84/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0051 - precision: 1.0000 - recall: 0.9983 - val_loss: 0.5508 - val_precision: 0.8381 - val_recall: 0.7648
# Epoch 85/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0048 - precision: 1.0000 - recall: 0.9995 - val_loss: 0.5533 - val_precision: 0.8372 - val_recall: 0.7656
# Epoch 86/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0046 - precision: 1.0000 - recall: 0.9999 - val_loss: 0.5541 - val_precision: 0.8381 - val_recall: 0.7657
# Epoch 87/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0044 - precision: 1.0000 - recall: 0.9996 - val_loss: 0.5575 - val_precision: 0.8381 - val_recall: 0.7665
# Epoch 88/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0043 - precision: 1.0000 - recall: 0.9997 - val_loss: 0.5597 - val_precision: 0.8385 - val_recall: 0.7668
# Epoch 89/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0040 - precision: 1.0000 - recall: 0.9996 - val_loss: 0.5614 - val_precision: 0.8392 - val_recall: 0.7657
# Epoch 90/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0038 - precision: 1.0000 - recall: 0.9997 - val_loss: 0.5635 - val_precision: 0.8385 - val_recall: 0.7665
# Epoch 91/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0038 - precision: 1.0000 - recall: 0.9999 - val_loss: 0.5657 - val_precision: 0.8384 - val_recall: 0.7663
# Epoch 92/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0037 - precision: 1.0000 - recall: 0.9995 - val_loss: 0.5684 - val_precision: 0.8380 - val_recall: 0.7668
# Epoch 93/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0036 - precision: 1.0000 - recall: 0.9996 - val_loss: 0.5708 - val_precision: 0.8371 - val_recall: 0.7668
# Epoch 94/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0035 - precision: 1.0000 - recall: 0.9996 - val_loss: 0.5727 - val_precision: 0.8380 - val_recall: 0.7666
# Epoch 95/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0033 - precision: 1.0000 - recall: 0.9996 - val_loss: 0.5744 - val_precision: 0.8378 - val_recall: 0.7669
# Epoch 96/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0032 - precision: 1.0000 - recall: 0.9998 - val_loss: 0.5769 - val_precision: 0.8372 - val_recall: 0.7665
# Epoch 97/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0030 - precision: 1.0000 - recall: 0.9999 - val_loss: 0.5781 - val_precision: 0.8383 - val_recall: 0.7665
# Epoch 98/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0029 - precision: 1.0000 - recall: 0.9997 - val_loss: 0.5807 - val_precision: 0.8370 - val_recall: 0.7671
# Epoch 99/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0029 - precision: 1.0000 - recall: 0.9999 - val_loss: 0.5828 - val_precision: 0.8380 - val_recall: 0.7672
# Epoch 100/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0028 - precision: 1.0000 - recall: 0.9999 - val_loss: 0.5850 - val_precision: 0.8389 - val_recall: 0.7665
# Epoch 101/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0028 - precision: 1.0000 - recall: 0.9999 - val_loss: 0.5863 - val_precision: 0.8401 - val_recall: 0.7663
# Epoch 102/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0027 - precision: 1.0000 - recall: 0.9999 - val_loss: 0.5891 - val_precision: 0.8394 - val_recall: 0.7665
# Epoch 103/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0026 - precision: 1.0000 - recall: 0.9998 - val_loss: 0.5911 - val_precision: 0.8385 - val_recall: 0.7662
# Epoch 104/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0025 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.5923 - val_precision: 0.8399 - val_recall: 0.7665
# Epoch 105/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0026 - precision: 1.0000 - recall: 0.9999 - val_loss: 0.5948 - val_precision: 0.8396 - val_recall: 0.7663
# Epoch 106/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0023 - precision: 1.0000 - recall: 0.9999 - val_loss: 0.5971 - val_precision: 0.8396 - val_recall: 0.7659
# Epoch 107/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0023 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.5987 - val_precision: 0.8403 - val_recall: 0.7665
# Epoch 108/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0023 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6013 - val_precision: 0.8387 - val_recall: 0.7660
# Epoch 109/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0022 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6028 - val_precision: 0.8388 - val_recall: 0.7665
# Epoch 110/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0022 - precision: 1.0000 - recall: 0.9999 - val_loss: 0.6049 - val_precision: 0.8395 - val_recall: 0.7662
# Epoch 111/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0021 - precision: 1.0000 - recall: 0.9998 - val_loss: 0.6074 - val_precision: 0.8392 - val_recall: 0.7666
# Epoch 112/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0020 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6089 - val_precision: 0.8391 - val_recall: 0.7668
# Epoch 113/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0020 - precision: 1.0000 - recall: 0.9999 - val_loss: 0.6112 - val_precision: 0.8385 - val_recall: 0.7663
# Epoch 114/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0019 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6129 - val_precision: 0.8387 - val_recall: 0.7663
# Epoch 115/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0019 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6149 - val_precision: 0.8384 - val_recall: 0.7663
# Epoch 116/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0019 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6169 - val_precision: 0.8395 - val_recall: 0.7654
# Epoch 117/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0018 - precision: 1.0000 - recall: 0.9999 - val_loss: 0.6192 - val_precision: 0.8386 - val_recall: 0.7662
# Epoch 118/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0018 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6204 - val_precision: 0.8388 - val_recall: 0.7653
# Epoch 119/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0017 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6228 - val_precision: 0.8387 - val_recall: 0.7662
# Epoch 120/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0016 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6245 - val_precision: 0.8392 - val_recall: 0.7651
# Epoch 121/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0016 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6258 - val_precision: 0.8389 - val_recall: 0.7653
# Epoch 122/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0016 - precision: 1.0000 - recall: 0.9999 - val_loss: 0.6284 - val_precision: 0.8377 - val_recall: 0.7653
# Epoch 123/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0016 - precision: 1.0000 - recall: 0.9999 - val_loss: 0.6302 - val_precision: 0.8386 - val_recall: 0.7662
# Epoch 124/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0015 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6311 - val_precision: 0.8401 - val_recall: 0.7648
# Epoch 125/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0015 - precision: 1.0000 - recall: 0.9999 - val_loss: 0.6340 - val_precision: 0.8387 - val_recall: 0.7657
# Epoch 126/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0015 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6355 - val_precision: 0.8395 - val_recall: 0.7648
# Epoch 127/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0014 - precision: 1.0000 - recall: 0.9999 - val_loss: 0.6384 - val_precision: 0.8376 - val_recall: 0.7659
# Epoch 128/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0014 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6398 - val_precision: 0.8381 - val_recall: 0.7657
# Epoch 129/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0013 - precision: 1.0000 - recall: 0.9999 - val_loss: 0.6416 - val_precision: 0.8375 - val_recall: 0.7656
# Epoch 130/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0014 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6436 - val_precision: 0.8388 - val_recall: 0.7656
# Epoch 131/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0013 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6458 - val_precision: 0.8386 - val_recall: 0.7662
# Epoch 132/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0012 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6467 - val_precision: 0.8394 - val_recall: 0.7662
# Epoch 133/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0012 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6490 - val_precision: 0.8383 - val_recall: 0.7660
# Epoch 134/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0012 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6508 - val_precision: 0.8384 - val_recall: 0.7662
# Epoch 135/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0012 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6525 - val_precision: 0.8379 - val_recall: 0.7654
# Epoch 136/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6550 - val_precision: 0.8378 - val_recall: 0.7659
# Epoch 137/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0011 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6561 - val_precision: 0.8381 - val_recall: 0.7660
# Epoch 138/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0011 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6595 - val_precision: 0.8368 - val_recall: 0.7659
# Epoch 139/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0011 - precision: 1.0000 - recall: 0.9999 - val_loss: 0.6601 - val_precision: 0.8390 - val_recall: 0.7660
# Epoch 140/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0010 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6625 - val_precision: 0.8382 - val_recall: 0.7659
# Epoch 141/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.9433e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6645 - val_precision: 0.8383 - val_recall: 0.7657
# Epoch 142/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.9645e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6666 - val_precision: 0.8384 - val_recall: 0.7663
# Epoch 143/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.6376e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6694 - val_precision: 0.8356 - val_recall: 0.7665
# Epoch 144/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.7821e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6702 - val_precision: 0.8392 - val_recall: 0.7659
# Epoch 145/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.4611e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6731 - val_precision: 0.8371 - val_recall: 0.7663
# Epoch 146/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.0908e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6750 - val_precision: 0.8373 - val_recall: 0.7665
# Epoch 147/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.1170e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6766 - val_precision: 0.8373 - val_recall: 0.7669
# Epoch 148/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.5975e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6786 - val_precision: 0.8380 - val_recall: 0.7656
# Epoch 149/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.7490e-04 - precision: 1.0000 - recall: 0.9999 - val_loss: 0.6806 - val_precision: 0.8380 - val_recall: 0.7657
# Epoch 150/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.2925e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6823 - val_precision: 0.8386 - val_recall: 0.7662
# Epoch 151/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.0788e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6849 - val_precision: 0.8369 - val_recall: 0.7668
# Epoch 152/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.9493e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6861 - val_precision: 0.8381 - val_recall: 0.7659
# Epoch 153/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.5498e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6893 - val_precision: 0.8366 - val_recall: 0.7666
# Epoch 154/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.6470e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6898 - val_precision: 0.8383 - val_recall: 0.7656
# Epoch 155/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.3504e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6921 - val_precision: 0.8380 - val_recall: 0.7657
# Epoch 156/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.1346e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6945 - val_precision: 0.8366 - val_recall: 0.7654
# Epoch 157/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.1862e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6951 - val_precision: 0.8391 - val_recall: 0.7653
# Epoch 158/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.9704e-04 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6988 - val_precision: 0.8396 - val_recall: 0.7660
# Epoch 159/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.0933e-04 - precision: 1.0000 - recall: 0.9999 - val_loss: 0.7039 - val_precision: 0.8309 - val_recall: 0.7659
# Epoch 160/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0088 - precision: 0.9959 - recall: 0.9910 - val_loss: 0.8651 - val_precision: 0.7427 - val_recall: 0.6379
# Epoch 161/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2124 - precision: 0.9018 - recall: 0.8010 - val_loss: 0.7721 - val_precision: 0.7617 - val_recall: 0.6266
# Epoch 162/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1240 - precision: 0.9430 - recall: 0.8459 - val_loss: 0.6913 - val_precision: 0.7936 - val_recall: 0.6944
# Epoch 163/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0403 - precision: 0.9832 - recall: 0.9313 - val_loss: 0.6669 - val_precision: 0.8052 - val_recall: 0.7329
# Epoch 164/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0152 - precision: 0.9955 - recall: 0.9662 - val_loss: 0.6610 - val_precision: 0.8144 - val_recall: 0.7542
# Epoch 165/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0076 - precision: 0.9992 - recall: 0.9893 - val_loss: 0.6633 - val_precision: 0.8170 - val_recall: 0.7660
# Epoch 166/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0054 - precision: 0.9997 - recall: 0.9934 - val_loss: 0.6605 - val_precision: 0.8203 - val_recall: 0.7682
# Epoch 167/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0040 - precision: 0.9999 - recall: 0.9973 - val_loss: 0.6615 - val_precision: 0.8185 - val_recall: 0.7725
# Epoch 168/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0034 - precision: 1.0000 - recall: 0.9979 - val_loss: 0.6651 - val_precision: 0.8194 - val_recall: 0.7716
# Epoch 169/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0031 - precision: 0.9999 - recall: 0.9985 - val_loss: 0.6674 - val_precision: 0.8207 - val_recall: 0.7734
# Epoch 170/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0029 - precision: 1.0000 - recall: 0.9983 - val_loss: 0.6686 - val_precision: 0.8204 - val_recall: 0.7730
# Epoch 171/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0026 - precision: 1.0000 - recall: 0.9994 - val_loss: 0.6709 - val_precision: 0.8187 - val_recall: 0.7739
# Epoch 172/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0025 - precision: 1.0000 - recall: 0.9996 - val_loss: 0.6720 - val_precision: 0.8219 - val_recall: 0.7739
# Epoch 173/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0024 - precision: 1.0000 - recall: 0.9999 - val_loss: 0.6742 - val_precision: 0.8188 - val_recall: 0.7745
# Epoch 174/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0023 - precision: 1.0000 - recall: 0.9995 - val_loss: 0.6748 - val_precision: 0.8212 - val_recall: 0.7733
# Epoch 175/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0022 - precision: 1.0000 - recall: 0.9997 - val_loss: 0.6766 - val_precision: 0.8208 - val_recall: 0.7743
# Epoch 176/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0020 - precision: 1.0000 - recall: 0.9999 - val_loss: 0.6782 - val_precision: 0.8212 - val_recall: 0.7730
# Epoch 177/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0019 - precision: 1.0000 - recall: 0.9997 - val_loss: 0.6800 - val_precision: 0.8208 - val_recall: 0.7734
# Epoch 178/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0019 - precision: 1.0000 - recall: 0.9999 - val_loss: 0.6809 - val_precision: 0.8208 - val_recall: 0.7728
# Epoch 179/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0018 - precision: 1.0000 - recall: 0.9999 - val_loss: 0.6827 - val_precision: 0.8206 - val_recall: 0.7734
# Epoch 180/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0017 - precision: 1.0000 - recall: 0.9998 - val_loss: 0.6835 - val_precision: 0.8205 - val_recall: 0.7734
# Epoch 181/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0017 - precision: 1.0000 - recall: 0.9999 - val_loss: 0.6853 - val_precision: 0.8217 - val_recall: 0.7734
# Epoch 182/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0016 - precision: 1.0000 - recall: 0.9998 - val_loss: 0.6863 - val_precision: 0.8212 - val_recall: 0.7733
# Epoch 183/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0016 - precision: 1.0000 - recall: 0.9998 - val_loss: 0.6873 - val_precision: 0.8231 - val_recall: 0.7730
# Epoch 184/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0015 - precision: 1.0000 - recall: 0.9999 - val_loss: 0.6890 - val_precision: 0.8224 - val_recall: 0.7734
# Epoch 185/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0015 - precision: 1.0000 - recall: 0.9999 - val_loss: 0.6911 - val_precision: 0.8234 - val_recall: 0.7737
# Epoch 186/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0015 - precision: 1.0000 - recall: 0.9999 - val_loss: 0.6919 - val_precision: 0.8246 - val_recall: 0.7731
# Epoch 187/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0014 - precision: 1.0000 - recall: 0.9999 - val_loss: 0.6935 - val_precision: 0.8241 - val_recall: 0.7739
# Epoch 188/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0013 - precision: 1.0000 - recall: 0.9998 - val_loss: 0.6947 - val_precision: 0.8246 - val_recall: 0.7734
# Epoch 189/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0013 - precision: 1.0000 - recall: 0.9999 - val_loss: 0.6957 - val_precision: 0.8253 - val_recall: 0.7731
# Epoch 190/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0013 - precision: 1.0000 - recall: 0.9999 - val_loss: 0.6971 - val_precision: 0.8250 - val_recall: 0.7736
# Epoch 191/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0012 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.6984 - val_precision: 0.8249 - val_recall: 0.7733
# Epoch 192/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0013 - precision: 1.0000 - recall: 0.9998 - val_loss: 0.7009 - val_precision: 0.8246 - val_recall: 0.7734
# Epoch 193/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0012 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7020 - val_precision: 0.8245 - val_recall: 0.7730
# Epoch 194/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0011 - precision: 1.0000 - recall: 0.9999 - val_loss: 0.7035 - val_precision: 0.8235 - val_recall: 0.7737
# Epoch 195/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0011 - precision: 1.0000 - recall: 0.9999 - val_loss: 0.7044 - val_precision: 0.8241 - val_recall: 0.7731
# Epoch 196/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0011 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7063 - val_precision: 0.8247 - val_recall: 0.7727
# Epoch 197/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0011 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.7073 - val_precision: 0.8244 - val_recall: 0.7730
# Epoch 198/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0011 - precision: 1.0000 - recall: 0.9999 - val_loss: 0.7087 - val_precision: 0.8249 - val_recall: 0.7721
# Epoch 199/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0010 - precision: 1.0000 - recall: 0.9998 - val_loss: 0.7105 - val_precision: 0.8242 - val_recall: 0.7725
# Epoch 200/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.9810e-04 - precision: 1.0000 - recall: 0.9999 - val_loss: 0.7117 - val_precision: 0.8247 - val_recall: 0.7721
# Train Precision: [1. 1. 1. 1. 1. 1.]
# Train Recall: [1.        1.        1.        1.        1.        0.9995283]
# Validation Precision: [0.7733217  0.80494505 0.8232514  0.82917464 0.85258967 0.8646999 ]
# Validation Recall: [0.7891459  0.7820285  0.77491105 0.76868325 0.76156586 0.75622773]

# %%
# 使用模型进行预测
Y_pred = model.predict(X_valid)

# 阈值处理，这里我们将0.5作为分类阈值
Y_pred_binary = (Y_pred > 0.5).astype(int)

# 计算平均精度
average_accuracy = accuracy_score(Y_valid, Y_pred_binary)
print("Average Accuracy:", average_accuracy)

# 计算宏观F1和微观F1
macro_f1 = f1_score(Y_valid, Y_pred_binary, average='macro')
micro_f1 = f1_score(Y_valid, Y_pred_binary, average='micro')
print("Macro F1 Score:", macro_f1)
print("Micro F1 Score:", micro_f1)

# 生成分类报告
report = classification_report(Y_valid, Y_pred_binary, target_names=[f'y_{i}' for i in range(Y_valid.shape[1])], zero_division=0)
print(report)

# 打印训练集和验证集上的最后一个epoch的精确率和召回率
print(f'Train Precision: {train_precision[-1]}')
print(f'Train Recall: {train_recall[-1]}')
print(f'Validation Precision: {val_precision[-1]}')
print(f'Validation Recall: {val_recall[-1]}')


# 使用模型进行预测获取概率输出
Y_pred_proba = model.predict(X_valid)

# 为每个类别绘制ROC曲线和计算AUC
plt.figure(figsize=(10, 8))
for i in range(Y_valid.shape[1]):
    fpr, tpr, _ = roc_curve(Y_valid.iloc[:, i], Y_pred_proba[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f'ROC curve (area = {roc_auc:.2f}) for label {i}')

plt.plot([0, 1], [0, 1], 'k--')  # 绘制对角线
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic for Each Class')
plt.legend(loc="lower right")
plt.show()

# 计算总的微观和宏观平均AUC
micro_auc = roc_auc_score(Y_valid, Y_pred_proba, average="micro")
macro_auc = roc_auc_score(Y_valid, Y_pred_proba, average="macro")
print("Micro-average AUC:", micro_auc)
print("Macro-average AUC:", macro_auc)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Average Accuracy: 0.6751412429378532
# Macro F1 Score: 0.7902162456384724
# Micro F1 Score: 0.7933212996389891
#               precision    recall  f1-score   support
#
#          y_0       0.78      0.74      0.76       102
#          y_1       0.77      0.77      0.77        87
#          y_2       0.89      0.76      0.82       102
#          y_3       0.72      0.86      0.78        98
#          y_4       0.85      0.78      0.82       102
#          y_5       0.75      0.77      0.76        84
#          y_6       0.85      0.73      0.79        96
#          y_7       0.78      0.85      0.82        96
#          y_8       0.83      0.88      0.85       142
#          y_9       0.87      0.71      0.78       110
#         y_10       0.79      0.71      0.75       105
#
#    micro avg       0.80      0.78      0.79      1124
#    macro avg       0.81      0.78      0.79      1124
# weighted avg       0.81      0.78      0.79      1124
#  samples avg       0.76      0.76      0.75      1124
#
# Train Precision: [1. 1. 1. 1. 1. 1.]
# Train Recall: [1.        1.        1.        1.        1.        0.9995283]
# Validation Precision: [0.7733217  0.80494505 0.8232514  0.82917464 0.85258967 0.8646999 ]
# Validation Recall: [0.7891459  0.7820285  0.77491105 0.76868325 0.76156586 0.75622773]
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 364us/step
# Micro-average AUC: 0.8781546693731774
# Macro-average AUC: 0.8752826771445328

# %%
# y_hat = model.predict(x_test)

# y_hat = (y_hat > 0.5).astype(int)

# print(y_hat)

# %%
# with open('predict.txt', 'w') as file:
#     for line in y_hat:
#         file.write(str(line)+'\n')
